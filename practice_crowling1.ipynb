# %% [markdown]
# <a href="https://colab.research.google.com/github/donoteatmushroom/practice_python/blob/main/practice_crowling1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install bs4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import bs4
import requests

# %%
url = 'https://search.shopping.naver.com/search/category/100005307'
result = requests.get(url).text
result
# Out:
# '<!DOCTYPE html><html lang="ko"><head><meta name="viewport" content="width=device-width"/><meta charSet="utf-8"/><title>네이버 쇼핑</title><link rel="shortcut icon" href="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-221019-193728/img/favicon.ico"/><meta property="og:title" content="네이버 쇼핑"/><meta property="og:image" content="https://ssl.pstatic.net/imgshopping/static/mo2014/icon/og_shopping_v2.png"/><meta property="og:description" content="네이버쇼핑 카테고리 검색 결과입니다"/><meta name="next-head-count" content="7"/><link rel="preconnect" href="https://static.nid.naver.com"/><link rel="preconnect" href="https://lcs.naver.com"/><link rel="preconnect" href="http://shopping.phinf.naver.net"/><link rel="preconnect" href="https://ssl.pstatic.net"/><link rel="preconnect" href="https://shopping-phinf.pstatic.net"/><link rel="preconnect" href="https://volts.shopping.naver.com"/><link rel="preload" href="https://ssl.pstatic.net/shoppingsearch/static/pc/pc-221019-193728/_next/static/css/49c7f5393b78dfc7.c
# ...

# %%
bsObj = bs4.BeautifulSoup(result,'html.parser')

# %%
items = bsObj.find_all('a', {'class':'basicList_link__JLQJf'})

# %%
for item in items:
  print(item.text)
# Out:
# 삼성전자 노트북 플러스2 NT550XDA-K14A
# LG전자 LG그램 16ZD90Q-SX76K
# 삼성전자 갤럭시북 프로360 NT950QDY-A51A
# 삼성전자 노트북 플러스2 NT550XDA-K14A
# 기본구성 SSD 128GB
# 68개
# SSD 256GB
# 45개
# SSD 500GB
# 43개
# SSD 1TB
# 28개
# 500GB + SSD 128GB
# 3개
# 1TB + SSD 128GB
# 6개
# 삼성전자 갤럭시북2 프로 NT950XEV-G51A
# 기본구성 SSD 256GB
# 35개
# SSD 500GB
# 37개
# SSD 1TB
# 49개
# SSD 2TB
# 6개
# SSD 256GB + SSD 256GB
# 6개
# SSD 500GB + SSD 256GB
# 6개

# %%
print(items[0].text)
print(items[1].text)
print(items[2].text)
print(items[3].text)
# Out:
# 삼성전자 노트북 플러스2 NT550XDA-K14A
# LG전자 LG그램 16ZD90Q-SX76K
# 삼성전자 갤럭시북 프로360 NT950QDY-A51A
# 삼성전자 노트북 플러스2 NT550XDA-K14A

# %%
for i in range(4):

  print(items[i].text)
# Out:
# 삼성전자 노트북 플러스2 NT550XDA-K14A
# LG전자 LG그램 16ZD90Q-SX76K
# 삼성전자 갤럭시북 프로360 NT950QDY-A51A
# 삼성전자 노트북 플러스2 NT550XDA-K14A
